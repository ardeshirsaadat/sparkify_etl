# %%
pip install psycopg2

# %%
pip install ipython-sql
# Out:
# Collecting ipython-sql
#   Using cached ipython_sql-0.4.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\users\ardes\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: six in c:\users\ardes\anaconda3\lib\site-packages (from ipython-sql) (1.16.0)
# Collecting sqlparse
#   Using cached sqlparse-0.4.2-py3-none-any.whl (42 kB)
# Collecting prettytable<1
#   Using cached prettytable-0.7.2.zip (28 kB)
# Requirement already satisfied: sqlalchemy>=0.6.7 in c:\users\ardes\anaconda3\lib\site-packages (from ipython-sql) (1.4.32)
# Requirement already satisfied: ipython>=1.0 in c:\users\ardes\anaconda3\lib\site-packages (from ipython-sql) (8.2.0)
# Requirement already satisfied: stack-data in c:\users\ardes\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\ardes\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ardes\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (3.0.20)
# Requirement already satisfied: decorator in c:\users\ardes\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: backcall in c:\users\ardes\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ardes\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (2.11.2)
# Requirement already satisfied: pickleshare in c:\users\ardes\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: colorama in c:\users\ardes\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.4.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\ardes\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\ardes\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.1.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\ardes\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (61.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ardes\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\ardes\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ardes\anaconda3\lib\site-packages (from sqlalchemy>=0.6.7->ipython-sql) (1.1.1)
# Requirement already satisfied: pure-eval in c:\users\ardes\anaconda3\lib\site-packages (from stack-data->ipython>=1.0->ipython-sql) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: asttokens in c:\users\ardes\anaconda3\lib\site-packages (from stack-data->ipython>=1.0->ipython-sql) (2.0.5)
# Requirement already satisfied: executing in c:\users\ardes\anaconda3\lib\site-packages (from stack-data->ipython>=1.0->ipython-sql) (0.8.3)
# Building wheels for collected packages: prettytable
#   Building wheel for prettytable (setup.py): started
#   Building wheel for prettytable (setup.py): finished with status 'done'
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13714 sha256=7b04963dcf04cdb355e74ac5b05e7d10f0e4356f5866bfa732f08b5e1950bb95
#   Stored in directory: c:\users\ardes\appdata\local\pip\cache\wheels\75\f7\28\77a076f1fa8cbeda61aca712815d04d7a32435f04a26a2dd7b
# Successfully built prettytable
# Installing collected packages: sqlparse, prettytable, ipython-sql
# Successfully installed ipython-sql-0.4.1 prettytable-0.7.2 sqlparse-0.4.2

# %%
pip install --upgrade ipython
# Out:
# Requirement already satisfied: ipython in c:\users\ardes\anaconda3\lib\site-packages (8.2.0)
# Collecting ipython
#   Downloading ipython-8.4.0-py3-none-any.whl (750 kB)
# Requirement already satisfied: backcall in c:\users\ardes\anaconda3\lib\site-packages (from ipython) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\ardes\anaconda3\lib\site-packages (from ipython) (61.2.0)
# Requirement already satisfied: stack-data in c:\users\ardes\anaconda3\lib\site-packages (from ipython) (0.2.0)
# Requirement already satisfied: matplotlib-inline in c:\users\ardes\anaconda3\lib\site-packages (from ipython) (0.1.2)
# Requirement already satisfied: decorator in c:\users\ardes\anaconda3\lib\site-packages (from ipython) (5.1.1)
# Requirement already satisfied: colorama in c:\users\ardes\anaconda3\lib\site-packages (from ipython) (0.4.4)
# Requirement already satisfied: traitlets>=5 in c:\users\ardes\anaconda3\lib\site-packages (from ipython) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\ardes\anaconda3\lib\site-packages (from ipython) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ardes\anaconda3\lib\site-packages (from ipython) (3.0.20)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ardes\anaconda3\lib\site-packages (from ipython) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\ardes\anaconda3\lib\site-packages (from ipython) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ardes\anaconda3\lib\site-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\ardes\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython) (0.2.5)
# Requirement already satisfied: pure-eval in c:\users\ardes\anaconda3\lib\site-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\ardes\anaconda3\lib\site-packages (from stack-data->ipython) (2.0.5)
# Requirement already satisfied: executing in c:\users\ardes\anaconda3\lib\site-packages (from stack-data->ipython) (0.8.3)
# Requirement already satisfied: six in c:\users\ardes\anaconda3\lib\site-packages (from asttokens->stack-data->ipython) (1.16.0)
# Installing collected packages: ipython
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.2.0
#     Uninstalling ipython-8.2.0:
#       Successfully uninstalled ipython-8.2.0
# Successfully installed ipython-8.4.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.

# %%
# %load_ext sql
# Out:
# C:\Users\ardes\anaconda3\lib\site-packages\numpy\__init__.py:148: UserWarning: mkl-service package failed to import, therefore Intel(R) MKL initialization ensuring its correct out-of-the box operation under condition when Gnu OpenMP had already been loaded by Python process is not assured. Please install mkl-service package, see http://github.com/IntelPython/mkl-service
#   from . import _distributor_init

# %%
import configparser
import psycopg2

# %%
config = configparser.ConfigParser()
config.read('dwh.cfg')

conn = psycopg2.connect("host={} dbname={} user={} password={} port={}".format(*config['CLUSTER'].values()))
cur = conn.cursor()

# %%
import os 
conn_string="postgresql://{}:{}@{}:{}/{}".format(config['CLUSTER'].get('DB_USER'),config['CLUSTER'].get('DB_PASSWORD'),config['CLUSTER'].get('HOST'),config['CLUSTER'].get('DB_PORT'),config['CLUSTER'].get('DB_NAME'))
print(conn_string)
# %sql $conn_string
# Out:
# postgresql://redshift:Redshift1@redshift-cluster-1.ct6yclxqz5o5.us-west-2.redshift.amazonaws.com:5439/dev

# %%
# Out:
#  * postgresql://redshift:***@redshift-cluster-1.ct6yclxqz5o5.us-west-2.redshift.amazonaws.com:5439/dev
# Done.
# []

# %%
# %%sql
# select * from stl_load_errors
# Out:
#  * postgresql://redshift:***@redshift-cluster-1.ct6yclxqz5o5.us-west-2.redshift.amazonaws.com:5439/dev
# 28 rows affected.
# [(100, 1, 105615, datetime.datetime(2022, 8, 18, 13, 48, 38, 758462), 1073857013, 102, 's3://udacity-dend/log_data/2018/11/2018-11-01-events.json                                                                                                                                                                                                       ', 1, 'artist                                                                                                                         ', 'char      ', '1         ', 0, '{"artist":null,"auth":"Logged In","firstName":"Walter","gender":"M","itemInSession":0,"lastName":"Frye","length":null,"level":"free","location":"San  ... (738 characters truncated) ...                                                                                                                                                      ', '{"artist":null,"auth":"Logged In","firstName":"Walter","gender":"M","itemInSession":0,"lastName":"Frye","length":null,"level":"free","location":"San  ... (738 characters truncated) ...                                                                                                                                                      ', 1214, 'Delimiter not found                                                                                 ', 0, 0),
#  (100, 1, 105619, datetime.datetime(2022, 8, 18, 14, 22, 26, 582040), 1073742787, 488, 's3://udacity-dend/log-data/2018/11/2018-11-01-events.json                                                                                                                                                                                                       ', 1, '                                                                                                                               ', '          ', '          ', 0, '1541105830796                                                                                                                                         ... (726 characters truncated) ...                                                                                                                                                      ', '                                                                                                                                                      ... (726 characters truncated) ...                                                                                                                                                      ', 1216, 'Overflow, Column type: Integer                                                                      ', 0, 0),
#  (100, 0, 105619, datetime.datetime(2022, 8, 18, 14, 22, 26, 573747), 1073742787, 488, 's3://udacity-dend/log-data/2018/11/2018-11-02-events.json                                                                                                                                                                                                       ', 1, '                                                                                                                               ', '          ', '          ', 0, '1541121934796                                                                                                                                         ... (726 characters truncated) ...                                                                                                                                                      ', '                                                                                                                                                      ... (726 characters truncated) ...                                                                                                                                                      ', 1216, 'Overflow, Column type: Integer                                                                      ', 0, 0),
#  (100, 1, 105646, datetime.datetime(2022, 8, 18, 15, 12, 30, 871291), 1073874669, 1028, 's3://udacity-dend/log-data/2018/11/2018-11-01-events.json                                                                                                                                                                                                       ', 1, '                                                                                                                               ', '          ', '          ', 0, '1541105830796                                                                                                                                         ... (726 characters truncated) ...                                                                                                                                                      ', '                                                                                                                                                      ... (726 characters truncated) ...                                                                                                                                                      ', 1216, 'Overflow, Column type: Integer                                                                      ', 0, 0),
#  (100, 0, 105646, datetime.datetime(2022, 8, 18, 15, 12, 30, 869825), 1073874669, 1028, 's3://udacity-dend/log-data/2018/11/2018-11-02-events.json                                                                                                                                                                                                       ', 1, '                                                                                                                               ', '          ', '          ', 0, '1541121934796                                                                                                                                         ... (726 characters truncated) ...                                                                                                                                                      ', '                                                                                                                                                      ... (726 characters truncated) ...                                                                                                                                                      ', 1216, 'Overflow, Column type: Integer                                                                      ', 0, 0),
#  (100, 1, 105673, datetime.datetime(2022, 8, 18, 15, 15, 57, 91879), 1073923902, 1062, 's3://udacity-dend/log-data/2018/11/2018-11-01-events.json                                                                                                                                                                                                       ', 1, 'artist                                                                                                                         ', 'char      ', '1         ', 0, '{"artist":null,"auth":"Logged In","firstName":"Walter","gender":"M","itemInSession":0,"lastName":"Frye","length":null,"level":"free","location":"San  ... (751 characters truncated) ... fari\\\\/537.36\\\\"","userId":"8"} {"artist":"Des\'ree","auth":"Logged In","firstName":"Kaylee","gender":"F","itemInSession":1,"lastName":"Summers",', '                                                                                                                                                      ... (726 characters truncated) ...                                                                                                                                                      ', 1213, 'Missing data for not-null field                                                                     ', 0, 0),
#  (100, 1, 105728, datetime.datetime(2022, 8, 18, 15, 24, 13, 569998), 1073907640, 1158, 's3://udacity-dend/log-data/2018/11/2018-11-01-events.json                                                                                                                                                                                                       ', 1, '                                                                                                                               ', '          ', '          ', 0, '1541105830796                                                                                                                                         ... (726 characters truncated) ...                                                                                                                                                      ', '                                                                                                                                                      ... (726 characters truncated) ...                                                                                                                                                      ', 1216, 'Overflow, Column type: Integer                                                                      ', 0, 0),
#  (100, 0, 105728, datetime.datetime(2022, 8, 18, 15, 24, 13, 565235), 1073907640, 1158, 's3://udacity-dend/log-data/2018/11/2018-11-02-events.json                                                                                                                                                                                                       ', 1, '                                                                                                                               ', '          ', '          ', 0, '1541121934796                                                                                                                                         ... (726 characters truncated) ...                                                                                                                                                      ', '                                                                                                                                                      ... (726 characters truncated) ...                                                                                                                                                      ', 1216, 'Overflow, Column type: Integer                                                                      ', 0, 0),
#  (100, 0, 105755, datetime.datetime(2022, 8, 18, 15, 27, 0, 343904), 1073776623, 1191, 's3://udacity-dend/log-data/2018/11/2018-11-01-events.json                                                                                                                                                                                                       ', 1, 'artist                                                                                                                         ', 'varchar   ', '256       ', 0, '{"artist":null,"auth":"Logged In","firstName":"Walter","gender":"M","itemInSession":0,"lastName":"Frye","length":null,"level":"free","location":"San  ... (751 characters truncated) ... fari\\\\/537.36\\\\"","userId":"8"} {"artist":"Des\'ree","auth":"Logged In","firstName":"Kaylee","gender":"F","itemInSession":1,"lastName":"Summers",', '                                                                                                                                                      ... (726 characters truncated) ...                                                                                                                                                      ', 1213, 'Missing data for not-null field                                                                     ', 0, 0),
#  (100, 1, 105782, datetime.datetime(2022, 8, 18, 15, 36, 45, 377886), 1073793143, 1304, 's3://udacity-dend/log-data/2018/11/2018-11-01-events.json                                                                                                                                                                                                       ', 1, 'length                                                                                                                         ', 'numeric   ', '18, 0     ', 0, '{"artist":null,"auth":"Logged In","firstName":"Walter","gender":"M","itemInSession":0,"lastName":"Frye","length":null,"level":"free","location":"San  ... (751 characters truncated) ... fari\\\\/537.36\\\\"","userId":"8"} {"artist":"Des\'ree","auth":"Logged In","firstName":"Kaylee","gender":"F","itemInSession":1,"lastName":"Summers",', '                                                                                                                                                      ... (726 characters truncated) ...                                                                                                                                                      ', 1213, 'Missing data for not-null field                                                                     ', 0, 0),
#  (100, 0, 105784, datetime.datetime(2022, 8, 18, 15, 40, 59, 372590), 1073899707, 1351, 's3://udacity-dend/log-data/2018/11/2018-11-01-events.json                                                                                                                                                                                                       ', 1, 'firstname                                                                                                                      ', 'varchar   ', '256       ', 0, '{"artist":null,"auth":"Logged In","firstName":"Walter","gender":"M","itemInSession":0,"lastName":"Frye","length":null,"level":"free","location":"San  ... (751 characters truncated) ... fari\\\\/537.36\\\\"","userId":"8"} {"artist":"Des\'ree","auth":"Logged In","firstName":"Kaylee","gender":"F","itemInSession":1,"lastName":"Summers",', '                                                                                                                                                      ... (726 characters truncated) ...                                                                                                                                                      ', 1213, 'Missing data for not-null field                                                                     ', 0, 0),
#  (100, 1, 105811, datetime.datetime(2022, 8, 18, 15, 44, 48, 328948), 1073883366, 1402, 's3://udacity-dend/log-data/2018/11/2018-11-01-events.json                                                                                                                                                                                                       ', 1, 'length                                                                                                                         ', 'numeric   ', '18, 0     ', 0, '{"artist":null,"auth":"Logged In","firstName":"Walter","gender":"M","itemInSession":0,"lastName":"Frye","length":null,"level":"free","location":"San  ... (751 characters truncated) ... fari\\\\/537.36\\\\"","userId":"8"} {"artist":"Des\'ree","auth":"Logged In","firstName":"Kaylee","gender":"F","itemInSession":1,"lastName":"Summers",', '                                                                                                                                                      ... (726 characters truncated) ...                                                                                                                                                      ', 1213, 'Missing data for not-null field                                                                     ', 0, 0),
#  (100, 0, 105841, datetime.datetime(2022, 8, 18, 15, 48, 7, 949147), 1073785137, 1448, 's3://udacity-dend/song-data/A/A/A/TRAAAAV128F421A322.json                                                                                                                                                                                                       ', 1, 'num_songs                                                                                                                      ', 'int4      ', '0         ', 0, '{"song_id": "SOQPWCR12A6D4FB2A3", "num_songs": 1, "title": "A Poor Recipe For Civic Cohesion", "artist_name": "Western Addiction", "artist_latitude": ... (726 characters truncated) ...                                                                                                                                                      ', '{"song_id": "SOQPWCR12A6D4FB2A3", "num_songs": 1, "title": "A Poor Recipe For Civic Cohesion", "artist_name": "Western Addiction", "artist_latitude": ... (726 characters truncated) ...                                                                                                                                                      ', 1214, 'Delimiter not found                                                                                 ', 0, 0),
#  (100, 1, 105841, datetime.datetime(2022, 8, 18, 15, 48, 7, 949147), 1073785137, 1448, 's3://udacity-dend/song-data/A/A/A/TRAAAAK128F9318786.json                                                                                                                                                                                                       ', 1, 'num_songs                                                                                                                      ', 'int4      ', '0         ', 0, '{"song_id": "SOBLFFE12AF72AA5BA", "num_songs": 1, "title": "Scream", "artist_name": "Adelitas Way", "artist_latitude": null, "year": 2009, "duration" ... (726 characters truncated) ...                                                                                                                                                      ', '{"song_id": "SOBLFFE12AF72AA5BA", "num_songs": 1, "title": "Scream", "artist_name": "Adelitas Way", "artist_latitude": null, "year": 2009, "duration" ... (726 characters truncated) ...                                                                                                                                                      ', 1214, 'Delimiter not found                                                                                 ', 0, 0),
#  (100, 0, 105873, datetime.datetime(2022, 8, 18, 15, 56, 18, 508101), 1073850827, 1545, 's3://udacity-dend/song-data/A/A/A/TRAAAAK128F9318786.json                                                                                                                                                                                                       ', 1, 'song_id                                                                                                                        ', 'varchar   ', '256       ', 0, '{"song_id": "SOBLFFE12AF72AA5BA", "num_songs": 1, "title": "Scream", "artist_name": "Adelitas Way", "artist_latitude": null, "year": 2009, "duration" ... (726 characters truncated) ...                                                                                                                                                      ', '{"song_id": "SOBLFFE12AF72AA5BA", "num_songs": 1, "title": "Scream", "artist_name": "Adelitas Way", "artist_latitude": null, "year": 2009, "duration" ... (726 characters truncated) ...                                                                                                                                                      ', 1214, 'Delimiter not found                                                                                 ', 0, 0),
#  (100, 1, 105873, datetime.datetime(2022, 8, 18, 15, 56, 18, 508101), 1073850827, 1545, 's3://udacity-dend/song-data/A/A/A/TRAAAAV128F421A322.json                                                                                                                                                                                                       ', 1, 'song_id                                                                                                                        ', 'varchar   ', '256       ', 0, '{"song_id": "SOQPWCR12A6D4FB2A3", "num_songs": 1, "title": "A Poor Recipe For Civic Cohesion", "artist_name": "Western Addiction", "artist_latitude": ... (726 characters truncated) ...                                                                                                                                                      ', '{"song_id": "SOQPWCR12A6D4FB2A3", "num_songs": 1, "title": "A Poor Recipe For Civic Cohesion", "artist_name": "Western Addiction", "artist_latitude": ... (726 characters truncated) ...                                                                                                                                                      ', 1214, 'Delimiter not found                                                                                 ', 0, 0),
#  (100, 0, 105875, datetime.datetime(2022, 8, 18, 15, 58, 40, 423441), 1073809917, 1573, 's3://udacity-dend/song-data/A/A/A/TRAAABD128F429CF47.json                                                                                                                                                                                                       ', 1, 'artist_latitude                                                                                                                ', 'int8      ', '0         ', 0, '{"song_id": "SOCIWDW12A8C13D406", "num_songs": 1, "title": "Soul Deep", "artist_name": "The Box Tops", "artist_latitude": 35.14968, "year": 1969, "du ... (726 characters truncated) ...                                                                                                                                                      ', '                                                                                                                                                      ... (726 characters truncated) ...                                                                                                                                                      ', 1207, "Invalid digit, Value '.', Pos 2, Type: Long                                                         ", 0, 0),
#  (100, 1, 105875, datetime.datetime(2022, 8, 18, 15, 58, 40, 423441), 1073809917, 1573, 's3://udacity-dend/song-data/A/A/A/TRAAAAV128F421A322.json                                                                                                                                                                                                       ', 1, 'artist_latitude                                                                                                                ', 'int8      ', '0         ', 0, '{"song_id": "SOQPWCR12A6D4FB2A3", "num_songs": 1, "title": "A Poor Recipe For Civic Cohesion", "artist_name": "Western Addiction", "artist_latitude": ... (726 characters truncated) ...                                                                                                                                                      ', '                                                                                                                                                      ... (726 characters truncated) ...                                                                                                                                                      ', 1207, "Invalid digit, Value '.', Pos 2, Type: Long                                                         ", 0, 0),
#  (100, 0, 105877, datetime.datetime(2022, 8, 18, 16, 5, 13, 199264), 1073777224, 1648, 's3://udacity-dend/song-data/A/A/A/TRAAAAV128F421A322.json                                                                                                                                                                                                       ', 1, 'song_id                                                                                                                        ', 'varchar   ', '256       ', 0, '{"song_id": "SOQPWCR12A6D4FB2A3", "num_songs": 1, "title": "A Poor Recipe For Civic Cohesion", "artist_name": "Western Addiction", "artist_latitude": ... (726 characters truncated) ...                                                                                                                                                      ', '{"song_id": "SOQPWCR12A6D4FB2A3", "num_songs": 1, "title": "A Poor Recipe For Civic Cohesion", "artist_name": "Western Addiction", "artist_latitude": ... (726 characters truncated) ...                                                                                                                                                      ', 1214, 'Delimiter not found                                                                                 ', 0, 0),
#  (100, 1, 105877, datetime.datetime(2022, 8, 18, 16, 5, 13, 199264), 1073777224, 1648, 's3://udacity-dend/song-data/A/A/A/TRAAAAK128F9318786.json                                                                                                                                                                                                       ', 1, 'song_id                                                                                                                        ', 'varchar   ', '256       ', 0, '{"song_id": "SOBLFFE12AF72AA5BA", "num_songs": 1, "title": "Scream", "artist_name": "Adelitas Way", "artist_latitude": null, "year": 2009, "duration" ... (726 characters truncated) ...                                                                                                                                                      ', '{"song_id": "SOBLFFE12AF72AA5BA", "num_songs": 1, "title": "Scream", "artist_name": "Adelitas Way", "artist_latitude": null, "year": 2009, "duration" ... (726 characters truncated) ...                                                                                                                                                      ', 1214, 'Delimiter not found                                                                                 ', 0, 0),
#  (100, 0, 105879, datetime.datetime(2022, 8, 18, 16, 17, 47, 204358), 1073900265, 1778, 's3://udacity-dend/song-data/A/A/A/TRAAAAV128F421A322.json                                                                                                                                                                                                       ', 1, 'song_id                                                                                                                        ', 'varchar   ', '256       ', 0, '{"song_id": "SOQPWCR12A6D4FB2A3", "num_songs": 1, "title": "A Poor Recipe For Civic Cohesion", "artist_name": "Western Addiction", "artist_latitude": ... (726 characters truncated) ...                                                                                                                                                      ', '{"song_id": "SOQPWCR12A6D4FB2A3", "num_songs": 1, "title": "A Poor Recipe For Civic Cohesion", "artist_name": "Western Addiction", "artist_latitude": ... (726 characters truncated) ...                                                                                                                                                      ', 1214, 'Delimiter not found                                                                                 ', 0, 0),
#  (100, 1, 105879, datetime.datetime(2022, 8, 18, 16, 17, 47, 204358), 1073900265, 1778, 's3://udacity-dend/song-data/A/A/A/TRAAAAK128F9318786.json                                                                                                                                                                                                       ', 1, 'song_id                                                                                                                        ', 'varchar   ', '256       ', 0, '{"song_id": "SOBLFFE12AF72AA5BA", "num_songs": 1, "title": "Scream", "artist_name": "Adelitas Way", "artist_latitude": null, "year": 2009, "duration" ... (726 characters truncated) ...                                                                                                                                                      ', '{"song_id": "SOBLFFE12AF72AA5BA", "num_songs": 1, "title": "Scream", "artist_name": "Adelitas Way", "artist_latitude": null, "year": 2009, "duration" ... (726 characters truncated) ...                                                                                                                                                      ', 1214, 'Delimiter not found                                                                                 ', 0, 0),
#  (100, 1, 105909, datetime.datetime(2022, 8, 18, 16, 22, 36, 182864), 1073818455, 1835, 's3://udacity-dend/song-data/A/Y/F/TRAYFUW128F428F618.json                                                                                                                                                                                                       ', 1, 'artist_location                                                                                                                ', 'varchar   ', '256       ', 0, '{"song_id": "SORMAXQ12A8C139224", "num_songs": 1, "title": "Landmines", "artist_name": "St. Vincent", "artist_latitude": 19.40904, "year": 2007, "dur ... (744 characters truncated) ...                                                                                                                                                      ', '                                                                                                                                                      ... (726 characters truncated) ...                                                                                                                                                      ', 1204, 'String length exceeds DDL length                                                                    ', 0, 0),
#  (100, 1, 105939, datetime.datetime(2022, 8, 18, 16, 55, 13, 739057), 1073941865, 2213, 's3://udacity-dend/song-data/A/Y/F/TRAYFUW128F428F618.json                                                                                                                                                                                                       ', 1, 'artist_location                                                                                                                ', 'varchar   ', '256       ', 0, '{"song_id": "SORMAXQ12A8C139224", "num_songs": 1, "title": "Landmines", "artist_name": "St. Vincent", "artist_latitude": 19.40904, "year": 2007, "dur ... (744 characters truncated) ...                                                                                                                                                      ', '                                                                                                                                                      ... (726 characters truncated) ...                                                                                                                                                      ', 1204, 'String length exceeds DDL length                                                                    ', 0, 0),
#  (100, 0, 105969, datetime.datetime(2022, 8, 18, 17, 15, 22, 785382), 1073860276, 2446, 's3://udacity-dend/song-data/A/Y/F/TRAYFUW128F428F618.json                                                                                                                                                                                                       ', 1, 'artist_location                                                                                                                ', 'varchar   ', '256       ', 0, '{"song_id": "SORMAXQ12A8C139224", "num_songs": 1, "title": "Landmines", "artist_name": "St. Vincent", "artist_latitude": 19.40904, "year": 2007, "dur ... (744 characters truncated) ...                                                                                                                                                      ', '                                                                                                                                                      ... (726 characters truncated) ...                                                                                                                                                      ', 1204, 'String length exceeds DDL length                                                                    ', 0, 0),
#  (100, 1, 105999, datetime.datetime(2022, 8, 18, 18, 25, 25, 480511), 1073771206, 3205, 's3://udacity-dend/song-data/B/B/Y/TRBBYQK128F425A300.json                                                                                                                                                                                                       ', 1, 'artist_name                                                                                                                    ', 'varchar   ', '256       ', 0, '{"song_id": "SOXYYWL12A8AE48475", "num_songs": 1, "title": "Feel Like Goin\' Home", "artist_name": "Spiritualized;Jason;Jason - Dulcimer/;Kate Radley ... (727 characters truncated) ...                                                                                                                                                      ', '                                                                                                                                                      ... (726 characters truncated) ...                                                                                                                                                      ', 1204, 'String length exceeds DDL length                                                                    ', 0, 0),
#  (100, 0, 106029, datetime.datetime(2022, 8, 18, 18, 45, 4, 614822), 1074000876, 3432, 's3://udacity-dend/song-data/A/Y/F/TRAYFUW128F428F618.json                                                                                                                                                                                                       ', 1, 'artist_location                                                                                                                ', 'varchar   ', '256       ', 0, '{"song_id": "SORMAXQ12A8C139224", "num_songs": 1, "title": "Landmines", "artist_name": "St. Vincent", "artist_latitude": 19.40904, "year": 2007, "dur ... (744 characters truncated) ...                                                                                                                                                      ', '                                                                                                                                                      ... (726 characters truncated) ...                                                                                                                                                      ', 1204, 'String length exceeds DDL length                                                                    ', 0, 0),
#  (100, 1, 106060, datetime.datetime(2022, 8, 18, 19, 5, 17, 638034), 1073861950, 3658, 's3://udacity-dend/song-data/J/V/L/TRJVLUK128F1483235.json                                                                                                                                                                                                       ', 1, 'title                                                                                                                          ', 'varchar   ', '256       ', 0, '{"song_id": "SONMHGO12A6D4F8E6A", "num_songs": 1, "title": "Marcha Do Cord\\\\u00e3o Da Bola Preta / Me D\\\\u00e1 Dinheiro A\\\\u00ed / Marcha Do Ga ... (745 characters truncated) ... cation": "California"}{"song_id": "SOJZZBL12A58A7711D", "num_songs": 1, "title": "A Sale Of Two Souls", "artist_name": "The Tangent", "artist_latitud', '                                                                                                                                                      ... (726 characters truncated) ...                                                                                                                                                      ', 1204, 'String length exceeds DDL length                                                                    ', 0, 0)]

# %%
# %%sql
# select * from staging_song limit 10
# Out:
#  * postgresql://redshift:***@redshift-cluster-1.ct6yclxqz5o5.us-west-2.redshift.amazonaws.com:5439/dev
# 10 rows affected.
# [('SOCIWDW12A8C13D406', 1, 'Soul Deep', 'The Box Tops', 35.14968, 1969, 148.03546, 'ARMJAGH1187FB546F3', -90.04892, 'Memphis, TN'),
#  ('SOIGICF12A8C141BC5', 1, 'Game & Watch', 'Son Kite', None, 2004, 580.54485, 'AREWD471187FB49873', None, ''),
#  ('SOOVHYF12A8C134892', 1, "I'll Be Waiting", 'Neal Schon', 37.54703, 1989, 304.56118, 'ARCLYBR1187FB53913', -122.31483, 'San Mateo, CA'),
#  ('SOBRKGM12A8C139EF6', 1, 'Welcome to the Pleasuredome', 'Frankie Goes To Hollywood', None, 1985, 821.05424, 'ARXQBR11187B98A2CC', None, 'Liverpool, England'),
#  ('SOHKNRJ12A6701D1F8', 1, 'Drop of Rain', 'Tweeterfriendly Music', None, 0, 189.57016, 'AR10USD1187B99F3F1', None, 'Burlington, Ontario, Canada'),
#  ('SOHOZBI12A8C132E3C', 1, 'Smash It Up', 'International Noise Conspiracy', None, 2000, 195.39546, 'AR0MWD61187B9B2B12', None, ''),
#  ('SOVROYO12AB0186D09', 1, 'Blood In Face', 'Suicide Commando', None, 2000, 287.29424, 'ARCZBX11187B9AD089', None, ''),
#  ('SOWBWRV12A6D4FB3D0', 1, 'I Know You', 'Mike Stern', None, 0, 307.46077, 'AR1LOGZ1187B990FB4', None, 'Boston, MA'),
#  ('SOGMORP12A8C13EF63', 1, 'Auburn and Ivory', 'Beach House', 39.29055, 2006, 270.00118, 'ARWCIEL1187FB42EF5', -76.6096, 'B-More'),
#  ('SONHGLD12AB0188D47', 1, 'Our Father', 'Anthony B', None, 1999, 202.4224, 'AR1S3NH1187B98C2BC', None, 'Clarks Town, Jamaica')]

# %%
# %%sql
# select * from staging_event limit 10
# Out:
#  * postgresql://redshift:***@redshift-cluster-1.ct6yclxqz5o5.us-west-2.redshift.amazonaws.com:5439/dev
# 10 rows affected.
# [('N.E.R.D. FEATURING MALICE', 'Logged In', 'Jayden', 'M', 0, 'Fox', Decimal('288'), 'free', 'New Orleans-Metairie, LA', 'PUT', 'NextSong', 1541033612796, 184, 'Am I High (Feat. Malice)', 200, '1541121934796', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', 101),
#  ('Death Cab for Cutie', 'Logged In', 'Stefany', 'F', 1, 'White', Decimal('216'), 'free', 'Lubbock, TX', 'PUT', 'NextSong', 1540708070796, 82, 'A Lack Of Color (Album Version)', 200, '1541122241796', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', 83),
#  ('Skillet', 'Logged In', 'Kevin', 'M', 0, 'Arellano', Decimal('178'), 'free', 'Harrisburg-Carlisle, PA', 'PUT', 'NextSong', 1540006905796, 153, 'Monster (Album Version)', 200, '1541126568796', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', 66),
#  (None, 'Logged In', 'Aiden', 'M', 0, 'Hess', None, 'free', 'La Crosse-Onalaska, WI-MN', 'GET', 'Home', 1540829025796, 170, None, 200, '1541129561796', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"', 86),
#  ('Kanye West', 'Logged In', 'Makinley', 'F', 0, 'Jones', Decimal('278'), 'free', 'Chicago-Naperville-Elgin, IL-IN-WI', 'PUT', 'NextSong', 1541091973796, 118, 'Family Business', 200, '1541135741796', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', 17),
#  ('Liz Callaway', 'Logged In', 'Lily', 'F', 0, 'Koch', Decimal('175'), 'paid', 'Chicago-Naperville-Elgin, IL-IN-WI', 'PUT', 'NextSong', 1541048010796, 172, 'Journey To The Past  (LP Version)', 200, '1541149281796', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"', 15),
#  (None, 'Logged In', 'Kynnedi', 'F', 0, 'Sanchez', None, 'free', 'Cedar Rapids, IA', 'GET', 'Home', 1541079034796, 88, None, 200, '1541149530796', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', 89),
#  ('OneRepublic', 'Logged In', 'Lily', 'F', 3, 'Koch', Decimal('224'), 'paid', 'Chicago-Naperville-Elgin, IL-IN-WI', 'PUT', 'NextSong', 1541048010796, 172, 'Secrets', 200, '1541149952796', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"', 15),
#  ('Brett Dennen', 'Logged In', 'Lily', 'F', 4, 'Koch', Decimal('179'), 'paid', 'Chicago-Naperville-Elgin, IL-IN-WI', 'PUT', 'NextSong', 1541048010796, 172, 'World Keeps Turning', 200, '1541150176796', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"', 15),
#  ('Anis', 'Logged In', 'Lily', 'F', 6, 'Koch', Decimal('246'), 'paid', 'Chicago-Naperville-Elgin, IL-IN-WI', 'PUT', 'NextSong', 1541048010796, 172, 'Swing Javanaise', 200, '1541150563796', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"', 15)]

# %%
# %%sql
# INSERT INTO songplay (start_time,user_id,level,song_id,artist_id,session_id,location,user_agent)
#     SELECT DISTINCT
#            TO_NUMBER(se.ts,'9999999999999') as start_time,
#            se.userId,
#            se.level,
#            ss.song_id,
#            ss.artist_id,
#            se.sessionId,
#            se.location,
#            se.userAgent
#
#     FROM staging_event se
#     Join staging_song ss ON (se.artist=ss.artist_name) AND (se.song=ss.title)
# Out:
#  * postgresql://redshift:***@redshift-cluster-1.ct6yclxqz5o5.us-west-2.redshift.amazonaws.com:5439/dev
# 333 rows affected.
# []

# %%
# %%sql
# drop table users
# Out:
#  * postgresql://redshift:***@redshift-cluster-1.ct6yclxqz5o5.us-west-2.redshift.amazonaws.com:5439/dev
# Done.
# []

# %%
# %%sql
# CREATE TABLE users(
#     user_id INT,
#     first_name VARCHAR,
#     last_name VARCHAR,
#     gender VARCHAR,
#     level VARCHAR
#     ) diststyle all;
# Out:
#  * postgresql://redshift:***@redshift-cluster-1.ct6yclxqz5o5.us-west-2.redshift.amazonaws.com:5439/dev
# Done.
# []

# %%
# %%sql
#     INSERT INTO users (user_id,first_name,last_name,gender,level)
#     SELECT DISTINCT
#            se.userid AS user_id,
#            se.firstName,
#            se.lastName,
#            se.gender,
#            se.level
#     FROM staging_event se
# Out:
#  * postgresql://redshift:***@redshift-cluster-1.ct6yclxqz5o5.us-west-2.redshift.amazonaws.com:5439/dev
# 107 rows affected.
# []

# %%
# %%sql
#     INSERT INTO song (song_id,title,artist_id,year,duration)
#     SELECT DISTINCT
#            ss.song_id AS song_id,
#            ss.title,
#            ss.artist_id,
#            ss.year,
#            ss.duration
#     FROM staging_song ss
# Out:
#  * postgresql://redshift:***@redshift-cluster-1.ct6yclxqz5o5.us-west-2.redshift.amazonaws.com:5439/dev
# 14896 rows affected.
# []

# %%
# %%sql
#     INSERT INTO artist (artist_id,name,location,lattitude,longtitude)
#     SELECT DISTINCT
#            ss.artist_id AS artist_id,
#            ss.artist_name,
#            ss.artist_location,
#            ss.artist_latitude,
#            ss.artist_longitude
#
#     FROM staging_song ss
# Out:
#  * postgresql://redshift:***@redshift-cluster-1.ct6yclxqz5o5.us-west-2.redshift.amazonaws.com:5439/dev
# 10025 rows affected.
# []

# %%
# %%sql
#     INSERT INTO time(start_time, hour, day, week, month, year, weekday)
#     SELECT DISTINCT ts, EXTRACT(HOUR FROM ts), EXTRACT(DAY FROM ts), EXTRACT(WEEK FROM ts), EXTRACT(MONTH FROM ts), EXTRACT(YEAR FROM ts), EXTRACT(WEEKDAY FROM ts)
#     FROM(
#        SELECT (TIMESTAMP 'epoch' + ts/1000 * INTERVAL '1 Second ') as ts
#        FROM staging_event)
# Out:
#  * postgresql://redshift:***@redshift-cluster-1.ct6yclxqz5o5.us-west-2.redshift.amazonaws.com:5439/dev
# 8023 rows affected.
# []

# %%
# %%sql
# select * from users limit 10
# Out:
#  * postgresql://redshift:***@redshift-cluster-1.ct6yclxqz5o5.us-west-2.redshift.amazonaws.com:5439/dev
# 10 rows affected.
# [(10, 'Sylvie', 'Cruz', 'F', 'free'),
#  (26, 'Ryan', 'Smith', 'M', 'free'),
#  (101, 'Jayden', 'Fox', 'M', 'free'),
#  (53, 'Celeste', 'Williams', 'F', 'free'),
#  (69, 'Anabelle', 'Simpson', 'F', 'free'),
#  (95, 'Sara', 'Johnson', 'F', 'paid'),
#  (89, 'Kynnedi', 'Sanchez', 'F', 'free'),
#  (80, 'Tegan', 'Levine', 'F', 'free'),
#  (100, 'Adler', 'Barrera', 'M', 'free'),
#  (61, 'Samuel', 'Gonzalez', 'M', 'free')]

# %%
# %%sql
# select * from songplay limit 10
# Out:
#  * postgresql://redshift:***@redshift-cluster-1.ct6yclxqz5o5.us-west-2.redshift.amazonaws.com:5439/dev
# 10 rows affected.
# [(237, 1541179905796, 10, 'free', 'SOHTKMO12AB01843B0', 'AR5EYTL1187B98EDA0', 182, 'Washington-Arlington-Alexandria, DC-VA-MD-WV', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"'),
#  (222, 1541267941796, 15, 'paid', 'SOHTKMO12AB01843B0', 'AR5EYTL1187B98EDA0', 199, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (268, 1541269150796, 95, 'paid', 'SOPANEB12A8C13E81E', 'ARSW5F51187FB4CFC9', 152, 'Winston-Salem, NC', '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"'),
#  (309, 1541273619796, 95, 'paid', 'SOYTFSY12A6D4FD84E', 'ARRFSMX1187FB39B03', 152, 'Winston-Salem, NC', '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"'),
#  (332, 1541312311796, 25, 'paid', 'SOQKCRV12AB018B431', 'AR1WKBM1187FB38900', 128, 'Marinette, WI-MI', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (158, 1541314272796, 25, 'paid', 'SORKKTY12A8C132F3E', 'ARIH5GU1187FB4C958', 128, 'Marinette, WI-MI', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (17, 1541316691796, 25, 'paid', 'SOHWVJJ12AB0185F6D', 'ARASYMJ1187B9ACAF2', 128, 'Marinette, WI-MI', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (297, 1541323143796, 44, 'paid', 'SOCSXKQ12A6D4F95A0', 'ARRE7IQ1187FB4CF13', 196, 'Waterloo-Cedar Falls, IA', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (224, 1541324515796, 44, 'paid', 'SOAFQGA12A8C1367FA', 'AR0IVTL1187B9AD520', 196, 'Waterloo-Cedar Falls, IA', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (261, 1541360115796, 73, 'paid', 'SOULTKQ12AB018A183', 'ARKQQZA12086C116FC', 72, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')]
